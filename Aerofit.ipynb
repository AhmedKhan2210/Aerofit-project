# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedKhan2210/Aerofit-project/blob/main/Aerofit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing required  libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading data set
df=pd.read_csv("aerofit_treadmill.csv")

# %%
#first five rows
df.head(5)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
#Fitness:self-rated ﬁtness on a 1-to-5 scale, where 1 is poor shape and 5 is the  excellent.

#Education:in years

# Usage:average number of times the customer plans to use the treadmill each week

#Miles:average number of miles the customer expects to walk/run each week


#checking shape of data
df.shape
# Out:
# (180, 9)

# %% [markdown]
# **Analysis**
#
#
# ---
#
#
# we have 180 records and 9 attributes(column)

# %%
#checking data type of all attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# **Analysis**
#
# ---
#
#
# It is showing that no null values in any column
#
# and most of the column are int type

# %%
#Statistical summary of descriptive analysis for Numerical column
df.describe().T
# Out:
#            count          mean           std      min       25%      50%  \
# Age        180.0     28.788889      6.943498     18.0     24.00     26.0
# Education  180.0     15.572222      1.617055     12.0     14.00     16.0
# Usage      180.0      3.455556      1.084797      2.0      3.00      3.0
# Fitness    180.0      3.311111      0.958869      1.0      3.00      3.0
# Income     180.0  53719.577778  16506.684226  29562.0  44058.75  50596.5
# Miles      180.0    103.194444     51.863605     21.0     66.00     94.0
#
#                 75%       max
# Age           33.00      50.0
# Education     16.00      21.0
# Usage          4.00       7.0
# Fitness        4.00       5.0
# Income     58668.00  104581.0
# Miles        114.75     360.0

# %% [markdown]
# **Analysis**
#
# ---
# 1. It shows that average age of people who use trademill is 28.7 years and minimum age is 18 and max age is 50 years.
#
# 2. The standard deviation of age being 6.9 indicates that the range of ages for the majority of people who use a treadmill lies between 21.8 years (28.7 - 6.9) and 36.6 years (28.7 + 6.9)
#
#
# 3. Many of these individuals have education beyond an undergraduate degree (we can conclude that most of the individual have under/post graduate degree)
#
# 4. Based on a standard deviation of 1.6 and a mean education level of 15.5, we can conclude that Education levels among treadmill users show minimal variance.
#
# 5. Usage of trademill each week on an avg is 3.4 times, and half(50th percentile) of the users plan to use use trademill 3 times or less.
#
# 6. Avg fitness rating is 3.3 which means most of the users rate themselves to be in moderate to good fitness, 25% of users rate their fitness at or below 3 (poor to moderate)
#
# 7. Avg income of trademill users are 53719 and there is significant variation in income level, some may have much higher or lower income than the avg
#
# 8. There is large variation in the number of miles run among users, with a wide range of distances observed. The average distance run is approximately 103.19 miles, but individual running distances vary significantly around this average.
#
#
# **Recommendation:**
# it's recommended for treadmill manufacturers or fitness centers to implement tailored marketing strategies and product features.
#
# Developing workout programs and features that cater to a wide age range, accommodating both younger and older users.
#
# Offering flexible pricing options and membership plans to cater to users with varying income levels.
#
# Providing personalized training programs or virtual coaching sessions to address the diverse fitness levels and goals observed among users.
#
# Emphasizing the versatility and effectiveness of treadmills in achieving fitness goals across different user demographics, backed by data on usage patterns and fitness levels.

# %%
#Statistical summary of descriptive analysis for object type column
df.describe(include="object").T
# Out:
#               count unique        top freq
# Product         180      3      KP281   80
# Gender          180      2       Male  104
# MaritalStatus   180      2  Partnered  107

# %% [markdown]
# **Analysis**
#
# ---
# 1. we have total 3 unique product in which KP281 is most frequently used
#
# 2. Male users or more comapre to female.
#
# 3. Partnered 107, it indicates that a significant portion of the sample is in a relationship or users who are married use more trademill

# %%
#Value Counts of product in percentage

Product_count = df["Product"].value_counts(normalize=True)*100
Product_count
# Out:
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222
# Name: Product, dtype: float64

# %% [markdown]
# 44% users preferred KP281 an entry level trademill, KP781 captured 22% market which is an advance level trademill

# %%
#Value Counts of age in percentage

Age_count= df["Age"].value_counts(normalize=True)*100
Age_count
# Out:
# 25    13.888889
# 23    10.000000
# 24     6.666667
# 26     6.666667
# 28     5.000000
# 35     4.444444
# 33     4.444444
# 30     3.888889
# 38     3.888889
# 21     3.888889
# 22     3.888889
# 27     3.888889
# 31     3.333333
# 34     3.333333
# 29     3.333333
# 20     2.777778
# 40     2.777778
# 32     2.222222
# 19     2.222222
# 48     1.111111
# 37     1.111111
# 45     1.111111
# 47     1.111111
# 46     0.555556
# 50     0.555556
# 18     0.555556
# 44     0.555556
# 43     0.555556
# 41     0.555556
# 39     0.555556
# 36     0.555556
# 42     0.555556
# Name: Age, dtype: float64

# %%
(len(df[(df["Age"]>=21) & (df["Age"]<=36)])/len(df))*100
# Out:
# 79.44444444444444

# %% [markdown]
# As we concluded earlier, the majority of people who use a treadmill fall between 21.8 years (28.7 - 6.9) and 36.6 years (28.7 + 6.9). We have now confirmed that approximately 80% of people fall within this range

# %%
#Education counts in percentage
Education_count= df["Education"].value_counts(normalize=True)*100
Education_count
# Out:
# 16    47.222222
# 14    30.555556
# 18    12.777778
# 15     2.777778
# 13     2.777778
# 12     1.666667
# 21     1.666667
# 20     0.555556
# Name: Education, dtype: float64

# %% [markdown]
# 47% of users with an education level of 16 use the treadmill.

# %%
#Level of eductaion who mostly use trademills
Education_count[(Education_count.index>=14) & (Education_count.index<=16)].sum()
# Out:
# 80.55555555555554

# %% [markdown]
# As we concluded before majority of users who use trademill have education range based on a standard deviation  15.5-1.6 = 13.9, and 15.5+1.6=17.1 Hence we can say that total data lies in this range is aprox 80 %.

# %%
Male_female_count = df["Gender"].value_counts(normalize=True)*100
Male_female_count=Male_female_count.round(2)
Male_female_count
# Out:
# Male      57.78
# Female    42.22
# Name: Gender, dtype: float64

# %% [markdown]
# Male percentage is 57% and female 42% who use trademill

# %%
Marital_status_count = df["MaritalStatus"].value_counts(normalize=True)*100
Marital_status_count=Marital_status_count.round(2)
Marital_status_count
# Out:
# Partnered    59.44
# Single       40.56
# Name: MaritalStatus, dtype: float64

# %% [markdown]
# Aprox 60% aerofit customers are married

# %%
#Checking Null Values in df
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# Found no missing values in any column

# %%
#Outliers Detection for Age column
df['Age'].describe()
# Out:
# count    180.000000
# mean      28.788889
# std        6.943498
# min       18.000000
# 25%       24.000000
# 50%       26.000000
# 75%       33.000000
# max       50.000000
# Name: Age, dtype: float64

# %%
q1 = np.percentile(df["Age"],25)
q3= np.percentile(df["Age"],75)
q1 , q3
# Out:
# (24.0, 33.0)

# %%
#IQR for Age
IQR= q3-q1
lower_outlier = q1-(1.5*IQR)
upper_outlier = q3+(1.5*IQR)
median = df["Age"].median()
print("IQR is : " ,IQR, ",Lower Outlier is : ",lower_outlier, ",upper outlier is : ",upper_outlier, ", Median is : ", median)
# Out:
# IQR is :  9.0 ,Lower Outlier is :  10.5 ,upper outlier is :  46.5 , Median is :  26.0

# %%
#Creating boxplot
sns.boxplot(data=df,y="Age")
plt.show()

# %% [markdown]
# **Analysis**
#
# ---
# All Values of age >46.5 or <10.5 considerd as outliers

# %%
(len(df[(df["Age"]>upper_outlier) | (df["Age"]<lower_outlier)])/len(df))*100
# Out:
# 2.7777777777777777

# %% [markdown]
# We have only 2.7% outliers in our Age column

# %%
#Outliers Detection for Income  column
df['Income'].describe()
# Out:
# count       180.000000
# mean      53719.577778
# std       16506.684226
# min       29562.000000
# 25%       44058.750000
# 50%       50596.500000
# 75%       58668.000000
# max      104581.000000
# Name: Income, dtype: float64

# %%
q1 = np.percentile(df["Income"],25)
q3= np.percentile(df["Income"],75)
q1 , q3
# Out:
# (44058.75, 58668.0)

# %%
#IQR for income
IQR= q3-q1
lower_outlier = q1-(1.5*IQR)
upper_outlier = q3+(1.5*IQR)
median = df["Income"].median()
print("IQR is : " ,IQR, ",Lower Outlier is : ",lower_outlier, ",upper outlier is : ",upper_outlier, ", Median is : ", median)
# Out:
# IQR is :  14609.25 ,Lower Outlier is :  22144.875 ,upper outlier is :  80581.875 , Median is :  50596.5

# %%
#Creating boxplot
sns.boxplot(data=df,x="Income")
plt.show()

# %%
(len(df[(df["Income"]>upper_outlier) | (df["Income"]<lower_outlier)])/len(df))*100
# Out:
# 10.555555555555555

# %% [markdown]
# **Analysis**
#
# ---
# As we can see 10.5% are outliers in our data of income column

# %%
df["Miles"].describe()
# Out:
# count    180.000000
# mean     103.194444
# std       51.863605
# min       21.000000
# 25%       66.000000
# 50%       94.000000
# 75%      114.750000
# max      360.000000
# Name: Miles, dtype: float64

# %%
#creating boxplot
sns.boxplot(data=df,x="Miles")
plt.show()

# %%
IQR=114-66
upper=114+(1.5*IQR)
lower=66-(1.5*IQR)
(len(df[(df["Miles"]>upper) | (df["Miles"]<lower)])/len(df))*100
# Out:
# 7.222222222222221

# %% [markdown]
# 7.2% outliers in Miles column

# %%
#Add New column for age group

df["Age_bracket"]= pd.cut(df["Age"], [17,30,40,50] , labels=["Young","Middle Age","Old Age"])

# %% [markdown]
# (17,30] - Young
#
# (30,40] - Middle Age
#
# (40,50] - Old Age

# %%
df["Age_bracket"].value_counts()
# Out:
# Young         120
# Middle Age     48
# Old Age        12
# Name: Age_bracket, dtype: int64

# %% [markdown]
# Most of the users are young

# %%
#Add New column for income group

df["Income_bracket"]=pd.cut(df['Income'],[29000,50000,75000,105000], labels=["low class","Middle class","Upper class"])
df["Income_bracket"].value_counts()
# Out:
# low class       83
# Middle class    76
# Upper class     21
# Name: Income_bracket, dtype: int64

# %% [markdown]
# Most of the users from Low and middle class

# %% [markdown]
# ---
#
# # **Univariate Analysis**

# %%
#Distribution of Trademill
plt.figure(figsize=(8,2))
plt.subplot(1,2,1)
sns.countplot(data=df,x="Product",hue="Product")
plt.xlabel("Trade mill")
plt.ylabel("Total users")

plt.subplot(1,2,2)
y=df["Product"].value_counts()
mylabels = df["Product"].unique()
myexplode=[0.03,0.03,0.03]
plt.pie(y, labels=mylabels, explode=myexplode, autopct="%1.1f%%")
plt.suptitle("Trademill Distribution")
plt.show()

# %% [markdown]
# **KP281**:- we can conclude that KP281 is very popular among users, it is an entry level trademill suggest that affordable for users.
#
# So need to focus on advertisment as budget friendly nature so that can get more customer attraction
#
# Hilight the key features of KP281 as an entry level to the fitness enthusiast
#
# Provide special offer to the customer who are looking for cost effective option
#
# ---
# **KP481**:- Target mid-level customers show case special fetaures and let them understand over what aspects KP481 better than KP281
#
# ---
# **KP781**:- Launch Targeted  marketing compaigns to increase interest and awareness among potential customers who are fitness freak and compare special fetaures to increase customer traffic
#
# **Recommendation**
#
# KP281 (Entry-Level Treadmill):
#
# Highlight its popularity among users and its affordability.
#
# Focus on advertising its budget-friendly nature to attract more customers.
#
# Key features to highlight:
# Affordable price point
# User-friendly interface
# Basic fitness tracking capabilities
#
# Provide special offers for customers seeking cost-effective options, such as discounted pricing or bundled accessories.
#
# KP481 (Mid-Level Treadmill):
#
# Target mid-level customers and emphasize how KP481 surpasses KP281 in various aspects.
#
# Showcase special features such as:
# Enhanced workout programs
#
# Advanced tracking metrics (heart rate, calories burned)
#
# Larger running surface for added comfort
#
# Educate customers about the benefits of investing in a mid-level treadmill for improved fitness experiences.
#
# KP781 (High-End Treadmill):
#
# Launch targeted marketing campaigns aimed at fitness enthusiasts.
#
# Increase interest and awareness by highlighting the unique features of KP781 compared to KP281 and KP481.
#
# Compare special features such as:
# Advanced incline and decline options for varied workouts
# Interactive touchscreen display with immersive workout experiences
# Integrated connectivity for streaming workouts and tracking progress
# Offer special promotions or discounts to encourage potential customers to try the high-end model

# %%
plt.figure(figsize=(17,15))
plt.subplot(3,4,1)
sns.countplot(data=df ,x="Gender", hue="Gender")
plt.title("Users Count by Gender", fontsize=8)

plt.subplot(3,4,2)
plt.pie(df["Gender"].value_counts(), labels=df["Gender"].unique(),autopct="%1.1f%%", explode=[0.05,0])
plt.title("Gender %", fontsize=8)

plt.subplot(3,4,3)
sns.countplot(data=df, x="MaritalStatus", palette="pastel")
plt.title("Marital Status compare", fontsize=8)

plt.subplot(3,4,4)
plt.pie(df["MaritalStatus"].value_counts(), labels=df["MaritalStatus"].unique(),explode=[0.03,0], autopct="%1.1f%%")
plt.title("Marital Status ratio", fontsize=8)

plt.subplot(3,4,6)
plt.pie(df["Income_bracket"].value_counts(), labels=df["Income_bracket"].unique(),autopct="%1.1f%%", explode=[0.03,0.03,0])
plt.title("Income Bracket Ratio",fontsize=8)

plt.subplot(3,4,5)
sns.countplot(data=df,x="Income_bracket",hue="Income_bracket")
plt.xticks(rotation=45)
plt.title("Users by Income class", fontsize=8)

plt.subplot(3,4,7)
plt.pie(df["Age_bracket"].value_counts(), labels=df["Age_bracket"].unique(),autopct="%1.1f%%", explode=[0.03,0.03,0])
plt.title("Age Bracket Ratio",fontsize=8)

plt.subplot(3,4,8)
sns.countplot(data=df,x="Age_bracket",hue="Age_bracket")
plt.xticks(rotation=45)
plt.title("Users by Age Group", fontsize=8)

plt.subplot(3,4,9)
sns.kdeplot(data=df, x="Fitness")
plt.title("Distribution of fitness level", fontsize=8)

plt.subplot(3,4,10)
sns.kdeplot(data=df, x="Education")
plt.title("Distribution of Education level", fontsize=8)

plt.subplot(3,4,11)
sns.kdeplot(data=df, x="Income")
plt.title("Distribution of Income level", fontsize=8)

plt.subplot(3,4,12)
sns.histplot(data=df, x="Miles")
plt.title("Distribution of Miles", fontsize=8)

plt.suptitle("Understanding of Univariate Analysis")
plt.subplots_adjust(hspace=0.65)
plt.show()
# Out:
# <ipython-input-33-546fd7fc5189>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="MaritalStatus", palette="pastel")

# %% [markdown]
# **Analysis**
#
# Gender and Marital Status: The majority of treadmill users are male, and there is a higher proportion of single individuals among them.
#
# Income and Education Levels: Treadmill usage is more prevalent among individuals with lower and middle-class income levels. Additionally, most users have attained education beyond the undergraduate level.
#
# Age Distribution: The demographic skew towards younger age groups indicates a higher propensity for treadmill usage among the youth compared to middle-aged and older individuals.
#
# Fitness Levels: The distribution of fitness ratings suggests that the majority of users rate themselves between moderate to good fitness levels.
#
# Running Distance: Users tend to cover distances ranging from 50 to 110 miles, indicating a consistent level of activity among treadmill users.
#
# **Recommendation**
#
# Targeted Marketing: Focus marketing efforts on segments with the highest representation, such as young, single individuals with lower to middle-class income levels. Tailor advertising messages to emphasize the affordability and accessibility of treadmills.
#
# Product Features and Pricing: Develop entry-level treadmill models with features that appeal to younger demographics, such as integrated workout programs and multimedia connectivity. Offer competitive pricing strategies to attract budget-conscious consumers.
#
# Education and Awareness: Launch educational campaigns highlighting the health benefits of treadmill exercise and the importance of regular physical activity, particularly among younger demographics. Partner with fitness influencers or health professionals to amplify messaging and reach target audiences effectively.
#
# Customer Engagement: Implement loyalty programs or rewards initiatives to incentivize continued usage and engagement among existing customers. Encourage user-generated content and testimonials to foster a sense of community and brand advocacy.
#
# Product Innovation: Invest in research and development to introduce innovative treadmill technologies that cater to evolving consumer preferences, such as interactive training experiences or gamification features.

# %% [markdown]
# # **Bivariate Analysis**

# %%
#Distribution of income bracket over each product

plt.figure(figsize=(17,7))
plt.subplot(2,3,1)
a=sns.countplot(data=df,x="Income_bracket",hue="Product", palette="Paired")
a.bar_label(a.containers[0])
a.bar_label(a.containers[1])
a.bar_label(a.containers[2])
plt.subplot(2,3,2)
sns.countplot(data=df,x="Age_bracket",hue="Product", palette="pastel")
plt.subplot(2,3,3)
sns.countplot(data=df,x="MaritalStatus",hue="Product", palette="deep")
plt.subplot(2,3,4)
sns.countplot(data=df,x="Gender",hue="Product", palette="muted")
plt.subplot(2,3,5)
sns.countplot(data=df,x="Education",hue="Product", palette="bright")
plt.subplot(2,3,6)
sns.countplot(data=df,x="Product",hue="Fitness", palette="bright")

plt.suptitle("Bivariate Analysis")
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# **Analysis**
#
# Among individuals with lower income levels, basic-level treadmills are the most common choice, whereas those in the middle class equally opt for basic and mid-level treadmills. Conversely, individuals in the upper class predominantly select advanced-level treadmills.
#
# Younger individuals typically favor basic-level treadmills, although they also exhibit a higher propensity for using mid and advanced-level models compared to other age groups. Middle-aged individuals tend to purchase more mid-level treadmills, while older adults show less interest in basic-level options but prefer mid and advanced-level treadmills.
#
# Regarding marital status, married individuals demonstrate a greater inclination towards purchasing mid and advanced-level treadmills compared to their single counterparts.
#
# In terms of gender, females are less likely to use advanced-level treadmills compared to males.
#
# Those with postgraduate degrees tend to opt for advanced-level treadmills, while individuals with undergraduate degrees predominantly prefer basic-level models.
#
#
# ---
# **Recommendation**
#
# Income Level:
#
# Target lower-income individuals with affordable basic treadmills, middle-income with options across basic and mid-level, and focus on advanced models for higher-income customers.
#
# Age Groups:
#
# Market basic treadmills to younger users, emphasize versatility and advanced features for mid-level, and durability for middle-aged and elderly users.
#
# Marital Status:
#
# Promote mid and advanced treadmills to married individuals, highlighting benefits for shared use.
#
# Gender:
#
# Encourage females to consider advanced treadmills, addressing usability concerns.
#
# Education Level:
#
# Highlight advanced features for postgraduates and affordability for undergraduates.

# %%
sns.heatmap(df.corr(),annot=True,fmt="0.2f")
plt.show()
# Out:
# <ipython-input-35-de4d0388c3e8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,fmt="0.2f")

# %% [markdown]
# 1: There is a moderate positive correlation between age and income, indicating
# that as individuals grow older, their income tends to increase.
#
# 2: Education and income are positively correlated, suggesting that individuals with higher levels of education tend to earn higher salaries.
#
# 3: There is a strong correlation between usage and miles, indicating that individuals who use the treadmill more frequently tend to cover longer distances.
#
# 4: Usage and fitness are positively correlated, implying that individuals who use the treadmill more often tend to rate themselves as being more physically fit.
#
# 5: There is a negative correlation between usage and age, suggesting that as people age, they tend to use the treadmill less frequently.
#
# 6: Fitness and miles are highly correlated, indicating that individuals who rate themselves as being physically fit tend to cover longer distances on the treadmill.
#
# 7: Fitness and age are negatively correlated, meaning that older individuals tend to rate themselves as being less physically fit compared to younger individuals.
#
#
#
#
# ---
#
# **Recommendation**
#
# 1: Promote Lifelong Fitness: Encourage individuals of all ages to engage in regular treadmill usage to maintain fitness levels as they age. Develop age-appropriate workout programs and incentives to motivate consistent treadmill use across different age groups.
#
#
# 2: Maximize Usage for Better Health: Encourage regular treadmill usage to improve overall fitness and health. Provide incentives such as rewards or challenges to motivate users to increase their treadmill activity and achieve better fitness outcomes.
#
# 3: Adapt to Changing Needs: Recognize that treadmill usage may decrease with age. Tailor marketing strategies and product offerings to cater to the needs and preferences of older adults, such as promoting low-impact workouts or adjustable intensity levels.
#
# 4: Monitor Fitness Progress: Implement fitness tracking features to help users monitor their progress and set achievable fitness goals. Provide personalized recommendations based on users' fitness levels and age to optimize their treadmill workouts.
#
# 5: Offer Varied Workout Options: Provide diverse workout programs and features to cater to users of different fitness levels and ages. Highlight the correlation between fitness and treadmill usage to motivate users to engage in regular exercise for better health outcomes.

# %% [markdown]
# # **Conditional and unconditional probabilities**

# %%
df.head(5)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0   KP281   18    Male         14        Single      3        4   29562
# 1   KP281   19    Male         15        Single      2        3   31836
# 2   KP281   19  Female         14     Partnered      4        3   30699
# 3   KP281   19    Male         12        Single      3        3   32973
# 4   KP281   20    Male         13     Partnered      4        2   35247
#
#    Miles Age_bracket Income_bracket
# 0    112       Young      low class
# 1     75       Young      low class
# 2     66       Young      low class
# 3     85       Young      low class
# 4     47       Young      low class

# %% [markdown]
# <font color="color: green;">#impact of gender on purchasing trademill.</font>

# %%
pd.crosstab(df["Gender"],
            df["Product"],
            margins=True,
            normalize="index"
            )
# Out:
# Product     KP281     KP481     KP781
# Gender
# Female   0.526316  0.381579  0.092105
# Male     0.384615  0.298077  0.317308
# All      0.444444  0.333333  0.222222

# %% [markdown]
# **For Females:**
#
# 52.63% of the females purchased Product KP281.
# 38.16% of the females purchased Product KP481.
# 9.21% of the females purchased Product KP781.
# Overall, among all females, Product KP281 is the most popular, followed by Product KP481, and then Product KP781.
#
# **For Males:**
#
# 38.46% of the males purchased Product KP281.
# 29.81% of the males purchased Product KP481.
# 31.73% of the males purchased Product KP781, So male percentage is more in buying KP781 than female so need to put more effort on showcasing extra features to increase more number of customer
# Overall, among all males, Product KP281 is the most popular, followed by Product KP781, and then Product KP481.
#
# **Overall:**
#
# When considering all individuals (both genders), Product KP281 is the most popular, followed by Product KP481, and then Product KP781.
#
#
# ---
# **Recommendation**
#
# Highlight the features of KP281 to appeal to both genders, as it is the most popular choice overall.
#
# Focus on showcasing the unique features of KP781 to attract more male customers, considering its higher popularity among males.
#
# Consider targeted marketing strategies to emphasize the specific benefits of each product for different demographic segments.

# %%
pd.crosstab(df["Gender"],
            df["Product"],
            margins=True,
            normalize=True)
# Out:
# Product     KP281     KP481     KP781       All
# Gender
# Female   0.222222  0.161111  0.038889  0.422222
# Male     0.222222  0.172222  0.183333  0.577778
# All      0.444444  0.333333  0.222222  1.000000

# %% [markdown]
# **For Females:**
#
# Among all females, 22.22% purchased Product KP281, 16.11% purchased Product KP481, and 3.89% purchased Product KP781.
# The total proportion of females in the dataset is 42.22%.
#
# **For Males:**
#
# Among all males, 22.22% purchased Product KP281, 17.22% purchased Product KP481, and 18.33% purchased Product KP781.
# The total proportion of males in the dataset is 57.78%.
#
# **Overall:**
#
# Among all individuals (both genders), 44.44% purchased Product KP281, 33.33% purchased Product KP481, and 22.22% purchased Product KP781.

# %% [markdown]
# <font color="color: green;">Probability of being Male/Female given that the individual purchased Product KP281/KP481/KP781:.</font>

# %%
pd.crosstab(df["Gender"],
            df['Product'],
            margins=True
            )
# Out:
# Product  KP281  KP481  KP781  All
# Gender
# Female      40     29      7   76
# Male        40     31     33  104
# All         80     60     40  180

# %% [markdown]
# **Probability of being female given that the individual purchased Product KP281:**
#
#
# P(Female | KP281)=
# 40/80 =0.5
#
# *Conclusion: Among customers who purchased Product KP281, there is possibilities that 50% of the customer is female.*
#
# **Probability of being female given that the individual purchased Product KP481:**
#
# P(Female | KP481)=
# 29/60 = 0.4833
#
# *Conclusion: Among customers who purchased Product KP481, approximately 48.33% were female.*
#
# **Probability of being female given that the individual purchased Product KP781:**
#
# P(Female | KP781)=
# 7/40 = 0.175
#
# *Conclusion: Among customers who purchased Product KP781, there is possibilities of 17.5% that the customer is female  *
#
# **Probability of being male given that the individual purchased Product KP281:**
#
# P(Male | KP281)=
# 40/80 =0.5
#
# *Conclusion: Among customers who purchased Product KP281, there is an equal probability of 50% that the customer is male.*
#
# **Probability of being male given that the individual purchased Product KP481:**
#
# P(Male | KP481)=
# 31/60=0.5167
#
# *Conclusion: Among customers who purchased Product KP481, approximately 51.67% were male.*
#
# **Probability of being male given that the individual purchased Product KP781:**
#
# P(Male | KP781)=
# 33/40 = 0.825
#
# *Conclusion: Among customers who purchased Product KP781, approximately 82.5% were male.*
#
#
# ---
#
# **Recommendation**
# To increase sales for KP281, focus on maintaining its appeal to both genders.
#
# For KP481, consider targeting marketing efforts towards both genders, but with a slight emphasis on males.
#
# For KP781, tailor marketing strategies to better resonate with male customers, highlighting features that appeal specifically to them. Additionally, explore ways to attract more female customers to balance the gender distribution.

# %% [markdown]
# <font color="color: green;">The impact of marital status on treadmill purchasing tendencies.</font>

# %%
pd.crosstab(df["MaritalStatus"],
            df["Product"],
            margins=True
            )
# Out:
# Product        KP281  KP481  KP781  All
# MaritalStatus
# Partnered         48     36     23  107
# Single            32     24     17   73
# All               80     60     40  180

# %% [markdown]
# **Probability of being partnered given that the individual purchased Product KP281:**
#
# P(Partnered | KP281)=
# 48/80=0.6
#
# *Conclusion: Among customers who purchased Product KP281, 60% were partnered*.
#
# **Probability of being partnered given that the individual purchased Product KP481:**
#
# P(Partnered | KP481)=
# 36/60 =0.6
#
# *Conclusion: Among customers who purchased Product KP481,there is 60% chance that the customer is partnered.*
#
# **Probability of being partnered given that the individual purchased Product KP781:**
#
# P(Partnered | KP781)=
# 23/40 =0.575
#
# *Conclusion: Among customers who purchased Product KP781, approximately 57.5% were partnered.*
#
# **Probability of being single given that the individual purchased Product KP281:**
#
# P(Single | KP281)=
# 32/80 =0.4
#
# *Conclusion: Among customers who purchased Product KP281, 40% were single.*
#
# **Probability of being single given that the individual purchased Product KP481:**
#
# P(Single | KP481)=
# 24/60=0.4
#
# *Conclusion: Among customers who purchased Product KP481, 40% were single.*
#
# **Probability of being single given that the individual purchased Product KP781**:
#
# P(Single | KP781)=
# 17/40 =0.425
#
# *Conclusion: Among customers who purchased Product KP781, approximately 42.5% were single.*

# %% [markdown]
# <font color="color: green;">The impact of age group on treadmill purchasing tendencies.</font>

# %%
pd.crosstab(df["Age_bracket"],
            df["Product"],
            margins=True
            ,normalize="index")
# Out:
# Product         KP281     KP481     KP781
# Age_bracket
# Young        0.458333  0.291667  0.250000
# Middle Age   0.395833  0.479167  0.125000
# Old Age      0.500000  0.166667  0.333333
# All          0.444444  0.333333  0.222222

# %% [markdown]
# **Age Bracket Influence on Product Preference:**
#
# Young individuals show a higher preference for Product KP281 compared to other age brackets, with a probability of approximately 45.83%.
#
# Middle-aged individuals demonstrate a higher preference for Product KP481, with a probability of approximately 47.92%.
#
# Old-aged individuals show a higher preference for Product KP281 and KP781 compared to KP481, with probabilities of 50% and 33.33% respectively.
#
# **Product Preferences Across Age Brackets**:
#
# Product KP281 is preferred by individuals in the Young and Old Age brackets, with probabilities of approximately 45.83% and 50% respectively.
#
# Product KP481 is preferred by individuals in the Middle Age bracket, with a probability of approximately 47.92%.
#
# Product KP781 shows varied preferences across age brackets, with the highest preference among individuals in the Old Age bracket (33.33%).

# %%
pd.crosstab(df["Product"],
            df["Age_bracket"],
            margins=True)
# Out:
# Age_bracket  Young  Middle Age  Old Age  All
# Product
# KP281           55          19        6   80
# KP481           35          23        2   60
# KP781           30           6        4   40
# All            120          48       12  180

# %%
#Age Bracket is given
pd.crosstab(df["Age_bracket"],
            df["Product"],
            margins=True,
            normalize="index")
# Out:
# Product         KP281     KP481     KP781
# Age_bracket
# Young        0.458333  0.291667  0.250000
# Middle Age   0.395833  0.479167  0.125000
# Old Age      0.500000  0.166667  0.333333
# All          0.444444  0.333333  0.222222

# %%
#Product is given
pd.crosstab(df["Product"],
            df["Age_bracket"],
            margins=True,
            normalize="index")
# Out:
# Age_bracket     Young  Middle Age   Old Age
# Product
# KP281        0.687500    0.237500  0.075000
# KP481        0.583333    0.383333  0.033333
# KP781        0.750000    0.150000  0.100000
# All          0.666667    0.266667  0.066667

# %% [markdown]
# **Probability of Age Bracket given Product:**
#
# P(Young | KP281)=
# 55/
# 80 =0.6875
#
# P(Middle Age | KP281)=
# 19/
# 80=0.2375
#
# P(Old Age | KP281)=
# 6/80
# =0.075
#
# P(Young | KP481)=
# 35/60 = 0.5833
#
# P(Middle Age | KP481)=
# 23/60= 0.3833
#
# P(Old Age | KP481)=
# 2/60 = 0.0333
#
# P(Young | KP781)=
# 30/40
# 30 =0.75
#
# P(Middle Age | KP781)=
# 6/40
# =0.15
#
# P(Old Age | KP781)=
# 4/40=0.1
#
# **Probability of Product given Age Bracket:**
#
# P(KP281 | Young)=
# 55/120= 0.4583
#
# P(KP481 | Young)=
# 35/120
# 35= 0.2917
#
# P(KP781 | Young)=
# 30/120 =0.25
#
# P(KP281 | Middle Age)=
# 19/48
# =0.3958
#
# P(KP481 | Middle Age)=
# 23/48
# =0.4792
#
# P(KP781 | Middle Age)=
# 6/48
# =0.125
#
# P(KP281 | Old Age)=
# 6/12
# =0.5
#
# P(KP481 | Old Age)=
# 2/12
# =0.1667
#
# P(KP781 | Old Age)=
# 4/12
# =0.3333

# %% [markdown]
# **Short Conclusion:**
#
# **Age Bracket given Product:**
#
# KP281: Preferred by 68.75% young, 23.75% middle-aged, and 7.5% old-aged individuals.
#
# KP481: Chosen by 58.33% young, 38.33% middle-aged, and 3.33% old-aged individuals.
#
# KP781: Favored by 75% young, 15% middle-aged, and 10% old-aged individuals.
#
# **Product given Age Bracket:**
#
# Young individuals: Prefer KP281 (45.83%), followed by KP481 (29.17%) and KP781 (25%).
#
# Middle-aged individuals: Favor KP481 (47.92%), then KP281 (39.58%), and KP781 (12.5%).
#
# Old-aged individuals: Primarily choose KP281 (50%), then KP781 (33.33%), and KP481 (16.67%).
#
# <font color="color: green;">**Unconditional Probabilities**.</font>
#
# Probability of Age Bracket:
#
# Young:
# 120/
# 180
# =
# 0.6667
#
# 66.67%
#
# Middle Age:
# 48/
# 180
# =
# 0.2667
#
#  26.67%
#
# Old Age:
# 12/
# 180
#
#  6.67%
#
# **Probability of Product:**
#
# KP281:
# 80/
# 180
# =
# 0.4444
#
#  44.44%
#
# KP481:
# 60/
# 180
# =0.3333
#
#  33.33%
#
# KP781:
# 40/
# 180
# =
# 0.2222
#
#  22.22%
#
# **conclusion**
#
#  Age Bracket:
#
# The majority of customer (66.67%) fall into the "Young" age bracket, followed by "Middle Age" (26.67%) and "Old Age" (6.67%).
# Product Preference:
#
# The most preferred product is KP281, accounting for 44.44% of all purchases, followed by KP481 (33.33%) and KP781 (22.22%).
#
#
# ---
# **Recommendation**
#
# Target marketing efforts for Product KP281 towards young and old-aged individuals, highlighting features that appeal to their demographics.
#
# Focus on promoting Product KP481 to middle-aged individuals, emphasizing its benefits and suitability for their age group.
#
# Develop targeted messaging for Product KP781, highlighting its versatility and appeal across different age brackets, particularly among older individuals.

# %% [markdown]
# <font color="color: green;">The impact of income group on treadmill purchasing tendencies.</font>

# %%
pd.crosstab(df["Income_bracket"],
            df["Product"],
            margins=True,
            normalize='index')
# Out:
# Product            KP281     KP481     KP781
# Income_bracket
# low class       0.578313  0.361446  0.060241
# Middle class    0.421053  0.394737  0.184211
# Upper class     0.000000  0.000000  1.000000
# All             0.444444  0.333333  0.222222

# %% [markdown]
# Low Class:
#
# Prefers KP281 (57.83%), followed by KP481 (36.15%) and least likely to purchase KP781 (6.02%).
#
# Middle Class:
#
# Shows a preference for KP281 (42.11%) and KP481 (39.47%), with a lower likelihood for KP781 (18.42%).
#
# Upper Class:
#
# Solely purchases KP781 (100%), indicating exclusive preference for this product.
#
#
# ---
# **Recommendation**
#
# Target marketing efforts for KP281 towards the low and middle class, highlighting its affordability and features that cater to their needs.
#
# Promote KP481 to both low and middle-class individuals, emphasizing its quality and versatility.
#
# Focus on showcasing the exclusivity and premium features of KP781 to appeal to the upper class, highlighting its luxury and advanced capabilities.

# %% [markdown]
# # **Outliers Detection Using Z-score**

# %%
df.head(5)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0   KP281   18    Male         14        Single      3        4   29562
# 1   KP281   19    Male         15        Single      2        3   31836
# 2   KP281   19  Female         14     Partnered      4        3   30699
# 3   KP281   19    Male         12        Single      3        3   32973
# 4   KP281   20    Male         13     Partnered      4        2   35247
#
#    Miles Age_bracket Income_bracket
# 0    112       Young      low class
# 1     75       Young      low class
# 2     66       Young      low class
# 3     85       Young      low class
# 4     47       Young      low class

# %%
#to iterate each column of datafram
outliers={}
for col in df.select_dtypes(include=np.number):
  z_scores=np.abs(df[col]-df[col].mean())/df[col].std()
  outliers_col = df[z_scores>3][col]
  outliers[col]=outliers_col

# %%
for col,outliers_values in outliers.items():
  print(f"Outliers for {col} column")
  print(outliers_values)
  print(50*"-")
# Out:
# Outliers for Age column
# 79    50
# Name: Age, dtype: int64
# --------------------------------------------------
# Outliers for Education column
# 157    21
# 161    21
# 175    21
# Name: Education, dtype: int64
# --------------------------------------------------
# Outliers for Usage column
# 163    7
# 166    7
# Name: Usage, dtype: int64
# --------------------------------------------------
# Outliers for Fitness column
# Series([], Name: Fitness, dtype: int64)
# --------------------------------------------------
# Outliers for Income column
# 168    103336
# 174    104581
# 178    104581
# Name: Income, dtype: int64
# --------------------------------------------------
# Outliers for Miles column
# 166    300
# 167    280
# 170    260
# 173    360
# Name: Miles, dtype: int64
# --------------------------------------------------

# %% [markdown]
# **Analysis**
#
# Age: One outlier with an age of 50 suggests a potential older user.
#
# Education: Several outliers with an education level of 21 might indicate individuals with lower educational attainment or data entry errors.
#
# Usage: Two outliers with a usage of 7 may represent heavy users of the treadmill.
#
# Fitness: No outliers were detected for the fitness column.
#
# Income: Three outliers with high incomes suggest affluent individuals in the dataset.
#
# Miles: Several outliers with high mileage values may represent individuals who engage in extensive running or data entry errors.

# %% [markdown]
# #**Descriptive Statistics for numerical column**

# %%
for col in df.select_dtypes(include=np.number):
  mean = df[col].mean()
  median = df[col].median()
  mode = df[col].mode()
  maximum = df[col].max()
  minimum = df[col].min()
  standard_deviation = df[col].std()
  q1 = np.percentile(df[col],25)
  q3 = np.percentile(df[col],75)
  IQR = q3-q1
  upper_whisker = q3+(1.5*IQR)
  lower_whisker = q1-(1.5*IQR)
  print(f"Discrptive stats for {col} column")

  print(f"Mean : {mean}")
  print(f"Median : {median}")
  print(f"Mode : {mode}")
  print(f"Max_value : {maximum}")
  print(f"Min_value : {minimum}")
  print(f"STD_value : {standard_deviation}")
  print(f"q1 : {q1}")
  print(f"q3 : {q3}")
  print(f"Internal_quartile_range : {IQR}")
  print(f"upper_outliers : {upper_whisker}")
  print(f"lower_outliers : {lower_whisker}")
  print()
  print(100*"*")
# Out:
# Discrptive stats for Age column
# Mean : 28.788888888888888
# Median : 26.0
# Mode : 0    25
# Name: Age, dtype: int64
# Max_value : 50
# Min_value : 18
# STD_value : 6.943498135399795
# q1 : 24.0
# q3 : 33.0
# Internal_quartile_range : 9.0
# upper_outliers : 46.5
# lower_outliers : 10.5
#
# ****************************************************************************************************
# Discrptive stats for Education column
# Mean : 15.572222222222223
# Median : 16.0
# Mode : 0    16
# Name: Education, dtype: int64
# Max_value : 21
# Min_value : 12
# STD_value : 1.6170548978065569
# q1 : 14.0
# q3 : 16.0
# Internal_quartile_range : 2.0
# upper_outliers : 19.0
# lower_outliers : 11.0
#
# ****************************************************************************************************
# Discrptive stats for Usage column
# Mean : 3.4555555555555557
# Median : 3.0
# Mode : 0    3
# Name: Usage, dtype: int64
# Max_value : 7
# Min_value : 2
# STD_value : 1.0847970343962436
# ...

# %% [markdown]
# **Analysis**
#
# **Age**: The average age is approximately 28.8 years, with a range from 18 to 50. The distribution is relatively symmetrical, with a median of 26 and a mode of 25. There are outliers at both ends of the range.
#
# **Education**: The mean education level is about 15.6, with most individuals having an education level around 16. The range is from 12 to 21, with outliers present at the lower end of the range.
#
# **Usage**: On average, individuals use the treadmill about 3.5 times per week, with a range from 2 to 7. The distribution is somewhat skewed, with a median of 3 and a mode of 3. There are outliers at both ends of the range.
#
# **Fitness**: The average self-rated fitness level is approximately 3.3, with a range from 1 to 5. The distribution is somewhat symmetrical, with a median and mode of 3. There are outliers at both ends of the range.
#
# **Income**: The average income is around $53,719, with a range from $29,562 to $104,581. The distribution is somewhat skewed, with outliers present at the higher end of the range.
#
# **Miles**: On average, individuals run approximately 103.2 miles, with a range from 21 to 360. The distribution is somewhat skewed, with outliers present at the higher end of the range.
#
# ---
# **Recommendation**+
#
# **Product Customization:** Analyze the preferences of different demographic segments to offer customized treadmill models.
#
# For example, considering the higher preference for Product KP281 among young individuals, Aerofit could introduce customizable options with features tailored to this demographic's needs. Additionally, based on the higher preference for Product KP781 among older individuals, Aerofit could develop models with enhanced comfort features and advanced technology to cater to this segment's preferences.
#
# **Price Segmentation:** Utilize price segmentation strategies based on income levels.
#
# Since the data suggests a preference for Product KP281 among lower-income individuals, Aerofit could introduce budget-friendly models while still maintaining quality and functionality. For middle and upper-income segments, focus on premium models such as Product KP781, offering advanced features and customization options.
#
# **Marketing Campaigns:** Develop targeted marketing campaigns to reach specific demographic segments. For instance, highlight the affordability and user-friendly features of Product KP281 in advertisements targeting younger individuals.
#
# For middle-aged customers, emphasize the durability and advanced workout programs of Product KP481.
#
# Tailor campaigns for older individuals by showcasing the health benefits and safety features of Product KP781.
#
# **Product Development:** Invest in research and development to enhance existing products and introduce innovative features.
#
# For example, based on the data's indication of usage and fitness being positively correlated, Aerofit could develop treadmills with integrated fitness tracking technology and personalized workout programs. Additionally, considering the outliers in the Income column, Aerofit could explore opportunities to introduce high-end models with premium features to attract affluent customers.
#
# **Customer Feedback Loop:** Establish a robust feedback mechanism to gather insights from customers. Encourage customers to provide feedback on their treadmill usage experience, including likes, dislikes, and suggestions for improvement.
#
# Analyze this feedback to continuously iterate and improve product offerings, ensuring they align with customer preferences and market demands
